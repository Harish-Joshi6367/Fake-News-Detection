# %%
import pandas as pd
import numpy as np

# %%
true = pd.read_csv("True.csv")
fake = pd.read_csv("Fake.csv")

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label'] = 1
fake['label'] = 0

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date  label
# 0  December 31, 2017       1
# 1  December 29, 2017       1
# 2  December 31, 2017       1
# 3  December 30, 2017       1
# 4  December 29, 2017       1

# %%
news = pd.concat([fake, true], axis = 0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(["title", "subject","date"], axis = 1)
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
#reshuffle data
news = news.sample(frac = 1)

# %%
news.reset_index(inplace = True)
news.head()
# Out:
#    index                                               text  label
# 0     92  Trump s economic adviser, Gary Cohn, has bough...      0
# 1  21018  This is really epic and just hysterical! It s ...      0
# 2   2290  BEDMINSTER, N.J. (Reuters) - Three military he...      1
# 3  13707  We ve heard it all before He was such a good b...      0
# 4  14520  NAIROBI (Reuters) - Kenya s police service sai...      1

# %%
news.drop(['index'], axis = 1, inplace = True)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Trump s economic adviser, Gary Cohn, has bough...      0
# 1  This is really epic and just hysterical! It s ...      0
# 2  BEDMINSTER, N.J. (Reuters) - Three military he...      1
# 3  We ve heard it all before He was such a good b...      0
# 4  NAIROBI (Reuters) - Kenya s police service sai...      1

# %%
#feature extraction
import re

def wordopt(text):
    # convert into lowercase
    text = text.lower()
    
    # remove URLs
    text = re.sub(r'https?://\S+|www\.\S+','', text)
    
    # remove HTML tags
    text = re.sub(r'<.*?>', '', text)
    
    # remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    
    # remove digits
    text = re.sub(r'\d', '', text)
    
    #remove newsline characters
    text = re.sub(r'\n', ' ', text)
    
    return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0        trump s economic adviser gary cohn has bought ...
# 1        this is really epic and just hysterical it s a...
# 2        bedminster nj reuters  three military helicopt...
# 3        we ve heard it all before he was such a good b...
# 4        nairobi reuters  kenya s police service said f...
#                                ...
# 44893    wikileaks founder julian assange has clearly s...
# 44894    here s something a lot of people may not know ...
# 44895    washington reuters  the partisan divide over t...
# 44896    washington reuters  the us senate voted unanim...
# 44897    tokyo reuters  a japanese man was killed in a ...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
x
# Out:
# 0        trump s economic adviser gary cohn has bought ...
# 1        this is really epic and just hysterical it s a...
# 2        bedminster nj reuters  three military helicopt...
# 3        we ve heard it all before he was such a good b...
# 4        nairobi reuters  kenya s police service said f...
#                                ...
# 44893    wikileaks founder julian assange has clearly s...
# 44894    here s something a lot of people may not know ...
# 44895    washington reuters  the partisan divide over t...
# 44896    washington reuters  the us senate voted unanim...
# 44897    tokyo reuters  a japanese man was killed in a ...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        1
#         ..
# 44893    0
# 44894    0
# 44895    1
# 44896    1
# 44897    1
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# %%
x_train.shape
# Out:
# (31428,)

# %%
x_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vector = TfidfVectorizer()

# %%
xv_train = vector.fit_transform(x_train)

# %%
xv_test = vector.transform(x_test)

# %%
xv_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 6471046 stored elements and shape (31428, 174144)>

# %%
xv_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2709128 stored elements and shape (13470, 174144)>

# %%
# create ml model
# 1. logistic regression
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9882702301410542

# %%
# 2. Decision tree calssifier
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()

# %%
DTC.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = LR.predict(xv_test)

# %%
DTC.score(xv_test, y_test)
# Out:
# 0.99547141796585

# %%
# predictive model for input data
def output_label(n):
    if n==0:
        return "It is a Fake News"
    elif n == 1:
        return "It is a Genuine News"

# %%
def manual_testing(news):
    testing_news = {"text" : [news]} # Corrected syntax for defining dictionary
    new_def_test = pd.DataFrame(testing_news)
    new_def_test["text"] = new_def_test["text"].apply(wordopt)
    new_x_test = new_def_test["text"]
    new_xv_test = vector.transform(new_x_test) # Assuming 'vector' is your vector object
    pred_lr = LR.predict(new_xv_test)
    pred_dtc = DTC.predict(new_xv_test)
    return "LR Prediction : {} \n dtc Prediction : {}".format(output_label(pred_lr[0]), output_label(pred_dtc[0]))

# %%
news_article = str(input())

# %%
manual_testing(news_article)
# Out:
# 'LR Prediction : It is a Fake News \n dtc Prediction : It is a Fake News'
